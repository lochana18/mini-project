# %%
import math
import datetime

def total_marks(a, b, c):
    return a + b + c

def percentage(total):
    return total / 3

name = input("Enter Student Name: ")
m1 = int(input("Enter Marks 1: "))
m2 = int(input("Enter Marks 2: "))
m3 = int(input("Enter Marks 3: "))

t = total_marks(m1, m2, m3)
p = percentage(t)

print("\n------ Student Report ------")
print("Name :", name)
print("Total :", t)
print("Percentage :", p)
print("Square Root :", math.sqrt(t))
print("Date & Time :", datetime.datetime.now())
# Out:
# Enter Student Name:  lochana
# Enter Marks 1:  95
# Enter Marks 2:  91
# Enter Marks 3:  98
# ------ Student Report ------
# Name : lochana
# Total : 284
# Percentage : 94.66666666666667
# Square Root : 16.852299546352718
# Date & Time : 2026-07-20 14:31:45.275343
